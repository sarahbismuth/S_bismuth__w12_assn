# %% [markdown]
# ### API key Generation
# ### URL: https://developer.nytimes.com/get-started
# ##### Register apps
#
# To register an app:
#
# Select My Apps from the user drop-down.
# Click + New App to create a new app.
# Enter a name and description for the app in the New App dialog.
# Click Create.
# Click the APIs tab.
# Click the access toggle to enable or disable access to an API product from the app.
#
# ##### Access the API keys
#
# Select My Apps from th user drop-down.
# Click the app in the list.
# View the API key on the App Details tab.
# Confirm that the status of the API key is Approved.

# %%
## importing the required libraries
import requests
import pandas as pd
from pandas.io.json import json_normalize  ## to normalize the data into dataframe
import json
from json2xml import json2xml

# %%
#Generate API key using above and store in the current folder inside apiKeyDetail.txt file
apiKey = open("./apiKeyDetail.txt", "r").readline()

# %% [markdown]
# ### Part I (18 points): Working with HTML, XML, and JSON
# Pick three of your favorite books on one of your favorite subjects. At least one of the books should have more than one author. For each book, include the title, authors, and two or three other attributes that you find interesting. Take the information that you’ve selected about these three books, and separately create three files which store the book’s information in HTML (using an html table), XML, and JSON formats (e.g. “books.html”, “books.xml”, and “books.json”). To help you better understand the different file structures, I’d prefer that you create each of these files “by hand” unless you’re already very comfortable with the file formats. Write Python code, using your packages of choice, to load the information from each of the three sources into separate PANDAS data frames. Are the three data frames identical? Your deliverable is the three source files and the Python code. Post the three source files to GitHub and package your Python code within a Jupyter notebook (along with your code for Part II below) and post it to GitHub as well.

# %%
apiBooks = 'https://api.nytimes.com/svc/books/v3/lists/best-sellers/history.json'

# %%
# function to read file using api and then return data in dictionary format
def returnJsonFile():
    dataApi=requests.get(apiBooks+'?api-key='+apiKey)
    dictData = dataApi.json()
    return dictData 

# function to call and receive dictionary. Then normalize data to dataframe.
def readBookData():
    dataJson = returnJsonFile()
    return json_normalize(dataJson['results'])

## generic function to write dataframe to file, need to provide dataframe, filename and extension of the file
def write2File(dfWrite,fileName = 'book', extFile= 'json'):
    nFile = open(fileName+"."+extFile, "w")
    nFile.write(dfWrite)
    nFile.close()

# %%
dfBooks = readBookData()

# %%
dfBooks.head()
# Out:
#                               title  \
# 0          "I GIVE YOU MY BODY ..."
# 1  "MOST BLESSED OF THE PATRIARCHS"
# 2                       #ASKGARYVEE
# 3                         #GIRLBOSS
# 4                       #IMOMSOHARD
#
#                                          description  \
# 0  The author of the Outlander novels gives tips ...
# 1  A character study that attempts to make sense ...
# 2  The entrepreneur expands on subjects addressed...
# 3  An online fashion retailer traces her path to ...
# 4
#
#                                 contributor  \
# 0                         by Diana Gabaldon
# 1  by Annette Gordon-Reed and Peter S. Onuf
# 2                        by Gary Vaynerchuk
# 3                         by Sophia Amoruso
# 4        by Kristin Hensley and Jen Smedley
#
#                                  author contributor_note  price age_group  \
# 0                        Diana Gabaldon                     0.0
# 1  Annette Gordon-Reed and Peter S Onuf                     0.0
# 2                       Gary Vaynerchuk                     0.0
# 3                        Sophia Amoruso                     0.0
# 4       Kristin Hensley and Jen Smedley                     0.0
#
#                   publisher  \
# 0                      Dell
# 1                 Liveright
# 2             HarperCollins
# 3  Portfolio/Penguin/Putnam
# 4                 HarperOne
#
#                                                isbns  \
# 0  [{'isbn10': '0399178570', 'isbn13': '978039917...
# 1  [{'isbn10': '0871404427', 'isbn13': '978087140...
# 2  [{'isbn10': '0062273124', 'isbn13': '978006227...
# 3  [{'isbn10': '039916927X', 'isbn13': '978039916...
# 4  [{'isbn10': '006285769X', 'isbn13': '978006285...
#
#                                        ranks_history  \
# 0  [{'primary_isbn10': '0399178570', 'primary_isb...
# 1  [{'primary_isbn10': '0871404427', 'primary_isb...
# 2  [{'primary_isbn10': '0062273124', 'primary_isb...
# 3  [{'primary_isbn10': '1591847931', 'primary_isb...
# 4  [{'primary_isbn10': '006285769X', 'primary_isb...
#
#                                              reviews
# 0  [{'book_review_link': '', 'first_chapter_link'...
# 1  [{'book_review_link': '', 'first_chapter_link'...
# 2  [{'book_review_link': '', 'first_chapter_link'...
# 3  [{'book_review_link': '', 'first_chapter_link'...
# 4  [{'book_review_link': '', 'first_chapter_link'...

# %%
# test for one particular title
#dfBook2authors = dfBooks[dfBooks['title'] == '"MOST BLESSED OF THE PATRIARCHS"'][['title','author','contributor','publisher']]

# %%
# Any author contains " and ", it is assumed that it has two authors
dfBook2authors = dfBooks[dfBooks['author'].str.contains(' and ')][['title','author','contributor','publisher']]

# %%
dfBook2authors
# Out:
#                               title                                author  \
# 1  "MOST BLESSED OF THE PATRIARCHS"  Annette Gordon-Reed and Peter S Onuf
# 4                       #IMOMSOHARD       Kristin Hensley and Jen Smedley
# 5                       #NEVERAGAIN            David Hogg and Lauren Hogg
#
#                                 contributor     publisher
# 1  by Annette Gordon-Reed and Peter S. Onuf     Liveright
# 4        by Kristin Hensley and Jen Smedley     HarperOne
# 5             by David Hogg and Lauren Hogg  Random House

# %%
#converting the data with more than 1 author and converting to html
htmlFile =dfBook2authors.to_html()

# %%
write2File(htmlFile, 'book','html')

# %%
# saving the file into html table
#html_file = open("book.html", "w")
#html_file.write(htmlFile)
#html_file.close()

# %%
## converting File to XML and Json
dfBooksAll= dfBooks[['title','author','contributor','publisher']]

# %% [markdown]
# ### Below function is to create XML file from the pandas dataframe and it is directed to "to_xml" so that it can be directly called from dataframe

# %%
def to_xml(df, filename=None, mode='w'):
    def row_to_xml(row):
        xml = ['<item>']
        for i, col_name in enumerate(row.index):
            xml.append('  <field name="{0}">{1}</field>'.format(col_name, row.iloc[i]))
        xml.append('</item>')
        return '\n'.join(xml)
    res = '\n'.join(df.apply(row_to_xml, axis=1))

    if filename is None:
        return res
    with open(filename, mode) as f:
        f.write(res)

pd.DataFrame.to_xml = to_xml

# %%
#converting the data with more than 1 author and converting to XML
xmlFile =dfBooksAll.to_xml()

# %%
write2File(xmlFile, 'book','xml')

# %%
# saving the file into html table
#xml_file = open("book.xml", "w")
#xml_file.write(xmlFile)
#xml_file.close()

# %%
# extracting the data in json format
jsonFile =dfBooksAll.to_json()

# %%
write2File(jsonFile, 'book','json')

# %%
# saving the file into html table
#json_file = open("book.json", "w")
#json_file.write(jsonFile)
#json_file.close()

# %%
## another way to generate json2xml
## !pip install json2xml

# %%
xmlFile2 = json2xml.Json2xml(jsonFile).to_xml()

# %%
xmlFile2
# Out:
# '<all>{"title":{"0":"\\"I GIVE YOU MY BODY ...\\"","1":"\\"MOST BLESSED OF THE PATRIARCHS\\"","2":"#ASKGARYVEE","3":"#GIRLBOSS","4":"#IMOMSOHARD","5":"#NEVERAGAIN","6":"$100 STARTUP","7":"$20 PER GALLON","8":"\'57, Chicago","9":"\'ROCK OF AGES: \'\'ROLLING STONE\'\' HISTORY OF ROCK AND ROLL\'","10":"\'THE HIGH ROAD TO CHINA: GEORGE BOGLE, THE PANCHEN LAMA AND THE FIRST BRITISH EXPEDITION TO TIBET\'","11":"\'TIL DEATH","12":"\'TIL DEATH DO US PART","13":"\'Til Faith Do Us Part: How Interfaith Marriage is Transforming America","14":"\'TIS THE SEASON","15":"------, THAT\'S DELICIOUS","16":"...and the Horse He Rode In On: The People V. Kenneth Starr","17":".HACK G.U.   , VOL. 5","18":"1 Ragged Ridge Road","19":"1,000 PLACES TO SEE BEFORE YOU DIE"},"author":{"0":"Diana Gabaldon","1":"Annette Gordon-Reed and Peter S Onuf","2":"Gary Vaynerchuk","3":"Sophia Amoruso","4":"Kristin Hensley and Jen Smedley","5":"David Hogg and Lauren Hogg","6":"Chris Guillebeau","7":"Christopher Steiner","8":"Steve Monroe","9":"GEOFFREY STOKES, KEN TUCKER\' \'ED WARD","10":"KATE TELTSCHER","11":"Sharon Sala","12":"Amanda Quick","13":"Naomi Schaefer Riley","14":"Ron Carr","15":"Action Bronson with Rachel Wharton","16":"James Carville","17":"Hamazaki Tatsuya","18":"David Adams Richards","19":"Patricia Schultz"},"contributor":{"0":"by Diana Gabaldon","1":"by Annette Gordon-Reed and Peter S. Onuf","2":"by Gary Vaynerchuk","3":"by Sophia Amoruso","4":"by Kristin Hensley and Jen Smedley","5":"by David Hogg and Lauren Hogg","6":"by Chris Guillebeau","7":"by Christopher Steiner","8":null,"9":null,"10":null,"11":"by Sharon Sala","12":"by Amanda Quick","13":null,"14":"by Robyn Carr","15":"by Action Bronson with Rachel Wharton","16":null,"17":"by Hamazaki Tatsuya","18":null,"19":"by Patricia Schultz"},"publisher":{"0":"Dell","1":"Liveright","2":"HarperCollins","3":"Portfolio\\/Penguin\\/Putnam","4":"HarperOne","5":"Random House","6":"Crown Business","7":"Grand Central","8":null,"9":null,"10":null,"11":"Harlequin Mira","12":"Berkley","13":null,"14":"Harlequin Mira","15":"Abrams","16":null,"17":"TOKYOPOP","18":null,"19":"Workman"}}</all>'

# %% [markdown]
# ### Part II (12 points): Working with Web API’s
# The New York Times web site provides a rich set of APIs, as described here: https://developer.nytimes.com You’ll need to start by signing up for an API key.
# Your task is to then choose one of the New York Times APIs and construct an interface in Python to read JSON data accessible via the API and transform that data into a Pandas data frame that is suitable for use in data analysis work.

# %% [markdown]
# ###### Reading api key from the text file where api key is stored for security purpose

# %% [markdown]
# # Reading data from Movie Review API

# %%
apiMovieReview = 'https://api.nytimes.com/svc/movies/v2/reviews/search' ##search.json?query=godfather&api-key=yourkey

# %% [markdown]
# ##### Function created below to read data from api and return Json format
# ##### Function has  parameter where we can pass the movie name, if no movie is passed it will be defaulted to godfather movie as given in website API
# This function accepts the movie name and then add the moviename in api and api key value.
# Read data from URL and then return the data in json format

# %%
def readDataJson(searchMovie='godfather'):
    searchMovie = '?query=' + searchMovie
    dataApi=requests.get(apiMovieReview+'.json'+searchMovie+'&api-key='+apiKey)
    return dataApi.json()

# %%
# converting the json file to dictionary
jsonMovie = readDataJson('Titanic') # example1 - passing the value as titanic, it will search this word in all movie names and return the data

# %%
type(jsonMovie)
# Out:
# dict

# %%
# Using below json_normalize, converting the results data from dictionary in the dataframe
dfMovie = json_normalize(jsonMovie['results'])

# %%
dfMovie.head() # showing 5 records from the data
# Out:
#                     display_title mpaa_rating  critics_pick          byline  \
# 0                    Titanic Town                         0  STEPHEN HOLDEN
# 1  The Chambermaid on the Titanic                         1  Stephen Holden
# 2                         Titanic       PG-13             1    Janet Maslin
# 3               Raise the Titanic          PG             0    JANET MASLIN
#
#                                     headline  \
# 0                     Titanic Town (Movie)
# 1  Chambermaid on the Titanic, The (Movie)
# 2                          Titanic (Movie)
# 3                  Raise the Titanic (Movie)
#
#                                        summary_short publication_date  \
# 0  Belfast housewife turns peace activist. Beauti...       2000-09-01
# 1  French foundry worker eroticizes his one-night...       1998-08-14
# 2  For once, a much-touted event movie is exactly...       1997-12-19
# 3              No, don't! Adventureless salvage job.       1980-08-01
#
#   opening_date         date_updated multimedia link.type  \
# 0         None  2017-11-02 04:16:14       None   article
# 1   1998-08-14  2017-11-02 04:17:55       None   article
# 2   1997-12-19  2017-11-02 04:17:54       None   article
# 3   1980-08-01  2017-11-02 04:17:30       None   article
#
#                                             link.url  \
# 0  http://www.nytimes.com/2000/09/01/movies/film-...
# 1  http://www.nytimes.com/1998/08/14/movies/film-...
# 2  http://www.nytimes.com/1997/12/19/movies/film-...
# 3  http://www.nytimes.com/1980/08/01/archives/rai...
#
#                             link.suggested_link_text
# 0     Read the New York Times Review of Titanic Town
# 1  Read the New York Times Review of The Chamberm...
# 2          Read the New York Times Review of Titanic
# 3  Read the New York Times Review of Raise the Ti...

# %% [markdown]
# ### Example 2 to read MOSTPOPULAR API to get different data

# %% [markdown]
# ## Three Example API
# https://api.nytimes.com/svc/mostpopular/v2/emailed/7.json?api-key=yourkey
# https://api.nytimes.com/svc/mostpopular/v2/shared/1/facebook.json?api-key=yourkey
# https://api.nytimes.com/svc/mostpopular/v2/viewed/1.json?api-key=yourkey

# %%
apiMostPopular =  'https://api.nytimes.com/svc/mostpopular/v2/' ## Common Url is stored in variable

# %%
def readmostPopularJson(jsonDtl,sharedType, period='1'):
    # emailed - most emailed article
    # shared - most shared
    # viewed - most viewed
    if jsonDtl == 'shared' and len(sharedType) !=0:
        jsonDtl = jsonDtl+'/'+str(period)+'/'+sharedType
    else:
        jsonDtl = jsonDtl+'/'+period
    dataApi=requests.get(apiMostPopular+jsonDtl+'.json?api-key='+apiKey)
    dictData = dataApi.json()
    return json_normalize(dictData['results'])

# %%
## most shared if we pass 1st parameter as shared
dfShared = readmostPopularJson('shared','facebook','1')

# %%
dfShared.head()
# Out:
#                                                  url  \
# 0  https://www.nytimes.com/2019/11/27/nyregion/hu...
# 1  https://www.nytimes.com/2019/11/27/opinion/tha...
# 2  https://www.nytimes.com/2019/11/29/us/politics...
# 3  https://www.nytimes.com/2019/11/29/health/new-...
# 4  https://www.nytimes.com/2019/11/28/arts/dance/...
#
#                                         adx_keywords subsection  share_count  \
# 0  Agriculture and Farming;Hull-O Farms (Durham, ...                       1
# 1  Pilgrims (Plymouth, Mass);Native Americans;Tha...                       2
# 2  Presidential Election of 2020;Harris, Kamala D...   politics            3
# 3  Therapy and Rehabilitation;Elderly;Nursing Hom...                       4
# 4  Dancing;Blacks;New York City Ballet;School of ...      dance            5
#
#         count_type            column  eta_id   section               id  \
# 0  SHARED-FACEBOOK              None       0  New York  100000006832232
# 1  SHARED-FACEBOOK              None       0   Opinion  100000006849251
# 2  SHARED-FACEBOOK              None       0      U.S.  100000006848078
# 3  SHARED-FACEBOOK   The New Old Age       0    Health  100000006844259
# 4  SHARED-FACEBOOK              None       0      Arts  100000006841890
#
#           asset_id  ...                                           abstract  \
# 0  100000006832232  ...  The aging owners of a Catskills farm say it “h...
# 1  100000006849251  ...  Before you fill your plate, please remember wh...
# 2  100000006848078  ...  Ms. Harris is the only 2020 Democrat who has f...
# 3  100000006844259  ...  Medicare revamped its reimbursement policy for...
# 4  100000006841890  ...  This year, for the first time, New York City B...
#
#   published_date              source              updated  \
# 0     2019-11-27  The New York Times  2019-11-29 16:52:08
# 1     2019-11-27  The New York Times  2019-11-29 18:15:19
# 2     2019-11-29  The New York Times  2019-11-30 04:35:46
# 3     2019-11-29  The New York Times  2019-11-29 10:02:01
# 4     2019-11-28  The New York Times  2019-11-29 16:32:21
#
#                                            des_facet  \
# 0                          [AGRICULTURE AND FARMING]
# 1  [PILGRIMS (PLYMOUTH, MASS), NATIVE AMERICANS, ...
# 2                    [PRESIDENTIAL ELECTION OF 2020]
# 3  [THERAPY AND REHABILITATION, ELDERLY, NURSING ...
# 4                                  [DANCING, BLACKS]
#
#                                            org_facet            per_facet  \
# 0  [HULL-O FARMS (DURHAM, NY), FAMILY BUSINESS, P...
# 1                                [INDIGENOUS PEOPLE]
# 2                           [PRIMARIES AND CAUCUSES]   [HARRIS, KAMALA D]
# 3  [MEDICARE, ELDER CARE, PHYSICAL THERAPY, HOME ...
# 4  [NEW YORK CITY BALLET, SCHOOL OF AMERICAN BALLET]  [NEBRES, CHARLOTTE]
#
#                           geo_facet  \
# 0            [CATSKILLS (NYS AREA)]
# 1  [PLYMOUTH (MASS), UNITED STATES]
# 2
# 3
# 4
#
#                                                media  \
# 0  [{'type': 'image', 'subtype': 'photo', 'captio...
# 1  [{'type': 'image', 'subtype': 'photo', 'captio...
# 2  [{'type': 'image', 'subtype': 'photo', 'captio...
# 3  [{'type': 'image', 'subtype': 'photo', 'captio...
# 4  [{'type': 'image', 'subtype': 'photo', 'captio...
#
#                                                  uri
# 0  nyt://article/713ed717-5920-5223-a5fa-c7d43b0b...
# 1  nyt://article/315b0797-8d77-5170-943a-6ef4adb0...
# 2  nyt://article/70bf6582-a21c-5d54-8207-6db42dcc...
# 3  nyt://article/0ce7be61-25e3-5af0-b0dc-900fd2b0...
# 4  nyt://article/499fed06-7340-5d7f-b3fa-1124ebe4...
#
# [5 rows x 24 columns]

# %%
## most viewed if we pass 1st parameter as viewed
dfViewed = readmostPopularJson('viewed','','1')

# %%
dfViewed.head()
# Out:
#                                                  url  \
# 0  https://www.nytimes.com/2019/11/29/us/politics...
# 1  https://www.nytimes.com/2019/11/27/opinion/tha...
# 2  https://www.nytimes.com/interactive/2019/books...
# 3  https://www.nytimes.com/2019/11/27/nyregion/hu...
# 4  https://www.nytimes.com/2019/11/29/world/europ...
#
#                                         adx_keywords column   section  \
# 0  Presidential Election of 2020;Harris, Kamala D...   None      U.S.
# 1  Pilgrims (Plymouth, Mass);Native Americans;Tha...   None   Opinion
# 2                                                               Books
# 3  Agriculture and Farming;Hull-O Farms (Durham, ...   None  New York
# 4  Bridges and Tunnels;Attacks on Police;Great Br...   None     World
#
#                                               byline         type  \
# 0  By JONATHAN MARTIN, ASTEAD W. HERNDON and ALEX...      Article
# 1                                 By CHARLES M. BLOW      Article
# 2                                                     Interactive
# 3                                 By COREY KILGANNON      Article
# 4                   By MARK LANDLER and MEGAN SPECIA      Article
#
#                                                title  \
# 0             How Kamala Harris’s Campaign Unraveled
# 1               The Horrible History of Thanksgiving
# 2                          100 Notable Books of 2019
# 3  After 240 Years and 7 Generations, Forced to S...
# 4  Stabbings Around London Bridge Kill 2 in ‘Terr...
#
#                                             abstract published_date  \
# 0  Ms. Harris is the only 2020 Democrat who has f...     2019-11-29
# 1  Before you fill your plate, please remember wh...     2019-11-27
# 2  The year’s notable fiction, poetry and nonfict...     2019-11-25
# 3  The aging owners of a Catskills farm say it “h...     2019-11-27
# 4  The authorities said that several people were ...     2019-11-29
#
#                source               id         asset_id  views  \
# 0  The New York Times  100000006848078  100000006848078      1
# 1  The New York Times  100000006849251  100000006849251      2
# 2  The New York Times  100000006844418  100000006844418      3
# 3  The New York Times  100000006832232  100000006832232      4
# 4  The New York Times  100000006851429  100000006851429      5
#
#                                            des_facet  \
# 0                    [PRESIDENTIAL ELECTION OF 2020]
# 1  [PILGRIMS (PLYMOUTH, MASS), NATIVE AMERICANS, ...
# 2
# 3                          [AGRICULTURE AND FARMING]
# 4           [BRIDGES AND TUNNELS, ATTACKS ON POLICE]
#
#                                            org_facet           per_facet  \
# 0                           [PRIMARIES AND CAUCUSES]  [HARRIS, KAMALA D]
# 1                                [INDIGENOUS PEOPLE]
# 2
# 3  [HULL-O FARMS (DURHAM, NY), FAMILY BUSINESS, P...
# 4
#
#                            geo_facet  \
# 0
# 1   [PLYMOUTH (MASS), UNITED STATES]
# 2
# 3             [CATSKILLS (NYS AREA)]
# 4  [GREAT BRITAIN, LONDON (ENGLAND)]
#
#                                                media  \
# 0  [{'type': 'image', 'subtype': 'photo', 'captio...
# 1  [{'type': 'image', 'subtype': 'photo', 'captio...
# 2  [{'type': 'image', 'subtype': 'photo', 'captio...
# 3  [{'type': 'image', 'subtype': 'photo', 'captio...
# 4  [{'type': 'image', 'subtype': 'photo', 'captio...
#
#                                                  uri
# 0  nyt://article/70bf6582-a21c-5d54-8207-6db42dcc...
# 1  nyt://article/315b0797-8d77-5170-943a-6ef4adb0...
# 2  nyt://interactive/d999ea9c-6a29-51f3-bcf3-6c1b...
# 3  nyt://article/713ed717-5920-5223-a5fa-c7d43b0b...
# 4  nyt://article/e9ab3f9d-2b1c-5e8c-9c85-d7beff2c...

# %%
## most emailed if we pass 1st parameter as emailed
dfEmailed = readmostPopularJson('emailed','','1')

# %%
dfEmailed.head()
# Out:
#                                                  url  \
# 0  https://www.nytimes.com/2019/11/27/opinion/tha...
# 1  https://www.nytimes.com/2019/11/28/opinion/bra...
# 2  https://www.nytimes.com/2019/11/28/opinion/tru...
# 3  https://www.nytimes.com/2019/11/27/movies/the-...
# 4  https://www.nytimes.com/2019/11/27/magazine/63...
#
#                                         adx_keywords subsection  email_count  \
# 0  Pilgrims (Plymouth, Mass);Native Americans;Tha...                       1
# 1  Brain;Vagus Nerve;Heart;Barrett, Lisa Feldman ...                       2
# 2  Thanksgiving Day;Trump, Donald J;Presidential ...                       3
# 3  Movies;The Irishman (Movie);I Heard You Paint ...                       4
# 4  Children and Childhood;Television;Documentary ...                       5
#
#   count_type column  eta_id   section               id         asset_id  ...  \
# 0    EMAILED   None       0   Opinion  100000006849251  100000006849251  ...
# 1    EMAILED   None       0   Opinion  100000006849074  100000006849074  ...
# 2    EMAILED   None       0   Opinion  100000006847913  100000006847913  ...
# 3    EMAILED   None       0    Movies  100000006831916  100000006831916  ...
# 4    EMAILED   None       0  Magazine  100000006838494  100000006838494  ...
#
#                                             abstract published_date  \
# 0  Before you fill your plate, please remember wh...     2019-11-27
# 1         You are not just thinking with your brain.     2019-11-28
# 2  My brother dishes on Trump, impeachment and th...     2019-11-28
# 3  The movie hits Netflix on Wednesday. Here’s a ...     2019-11-27
# 4  In 1964, with “Seven Up!” Michael Apted stumbl...     2019-11-27
#
#                source              updated  \
# 0  The New York Times  2019-11-29 18:15:19
# 1  The New York Times  2019-11-29 22:03:48
# 2  The New York Times  2019-11-29 22:03:48
# 3  The New York Times  2019-11-29 16:25:03
# 4  The New York Times  2019-11-29 23:08:54
#
#                                            des_facet  \
# 0  [PILGRIMS (PLYMOUTH, MASS), NATIVE AMERICANS, ...
# 1                                            [BRAIN]
# 2  [THANKSGIVING DAY, PRESIDENTIAL ELECTION OF 2020]
# 3         [MOVIES, ORGANIZED CRIME, ORGANIZED LABOR]
# 4                           [CHILDREN AND CHILDHOOD]
#
#                                            org_facet  \
# 0                                [INDIGENOUS PEOPLE]
# 1                               [VAGUS NERVE, HEART]
# 2
# 3  [NETFLIX INC, INTERNATIONAL BROTHERHOOD OF TEA...
# 4       [TELEVISION, DOCUMENTARY FILMS AND PROGRAMS]
#
#                                            per_facet  \
# 0
# 1  [BARRETT, LISA FELDMAN (1963- ), PORGES, STEPH...
# 2                                  [TRUMP, DONALD J]
# 3                   [HOFFA, JAMES R, SHEERAN, FRANK]
# 4                                   [APTED, MICHAEL]
#
#                           geo_facet  \
# 0  [PLYMOUTH (MASS), UNITED STATES]
# 1
# 2
# 3
# 4                   [GREAT BRITAIN]
#
#                                                media  \
# 0  [{'type': 'image', 'subtype': 'photo', 'captio...
# 1  [{'type': 'image', 'subtype': 'photo', 'captio...
# 2  [{'type': 'image', 'subtype': 'photo', 'captio...
# 3  [{'type': 'image', 'subtype': 'photo', 'captio...
# 4  [{'type': 'image', 'subtype': 'photo', 'captio...
#
#                                                  uri
# 0  nyt://article/315b0797-8d77-5170-943a-6ef4adb0...
# 1  nyt://article/3c4c308d-cf86-5598-9455-0348c83c...
# 2  nyt://article/abe360d5-8eb6-5d2a-8614-700b0d19...
# 3  nyt://article/eb29ac92-fdfe-54e1-a632-0de564bd...
# 4  nyt://article/fd549a1d-cba8-5269-bf74-6faa71eb...
#
# [5 rows x 24 columns]
